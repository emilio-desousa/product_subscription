# %% [markdown]
# # Product_Subscription : Phase Exploratoire
#
# ## Emilio de Sousa / Damien Mellot

# %%
import pandas as pd
import seaborn as sns
from matplotlib import rcParams
rcParams['figure.figsize'] = 20,10

# %%
df = pd.read_csv('../data/raw/data.csv', sep=";")
df.head()
# Out:
#          DATE  AGE       JOB_TYPE       STATUS   EDUCATION HAS_DEFAULT  \
# 0  2008-05-05   58        Manager        Marié   Tertiaire          No
# 1  2008-05-05  123     Technicien          NaN  Secondaire          No
# 2  2008-05-05   33  Entrepreuneur        Marié  Secondaire          No
# 3  2008-05-05   47       Col bleu        Marié         NaN          No
# 4  2008-05-05   33            NaN  Célibataire         NaN          No
#
#    BALANCE HAS_HOUSING_LOAN HAS_PERSO_LOAN CONTACT  DURATION_CONTACT  \
# 0     2143              Yes             No     NaN               261
# 1       29              Yes            NaN     NaN               151
# 2        2              Yes            Yes     NaN                76
# 3     1506              Yes             No     NaN                92
# 4        1               No             No     NaN               198
#
#    NB_CONTACT  NB_DAY_LAST_CONTACT  NB_CONTACT_LAST_CAMPAIGN  \
# ...

# %%
count_age_response_pct = pd.crosstab(df['SUBSCRIPTION'],df['AGE']).apply(lambda x: x/x.sum() * 100)

# %%
sns.countplot(x=df['AGE'], hue=df['SUBSCRIPTION'])
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='count'>

# %%
sn

# %%
sns.countplot(x=df['JOB_TYPE'])
sns.countplot(x=df['STATUS'])
sns.countplot(x=df['EDUCATION'])
sns.countplot(x=df['HAS_DEFAULT'])
# Out:
# <AxesSubplot:xlabel='HAS_DEFAULT', ylabel='count'>

# %%
test = df[df['BALANCE']<100000]['BALANCE']
df[df[df['BALANCE']<10000]].shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-4d1e0f6c8c41> in <module>
#       1 test = df[df['BALANCE']<100000]['BALANCE']
# ----> 2 df[df[df['BALANCE']<10000]].shape
#
# ~/Library/Caches/pypoetry/virtualenvs/productsubscription-eds-dm-ZQL7sEaB-py3.8/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2891         # Do we have a (boolean) DataFrame?
#    2892         if isinstance(key, DataFrame):
# -> 2893             return self.where(key)
#    2894
#    2895         # Do we have a (boolean) 1d indexer?
#
# ~/Library/Caches/pypoetry/virtualenvs/productsubscription-eds-dm-ZQL7sEaB-py3.8/lib/python3.8/site-packages/pandas/core/generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    9002         """
#    9003         other = com.apply_if_callable(other, self)
# -> 9004         return self._where(
# ...

# %%
sns.histplot(x=test, hue=df['SUBSCRIPTION'])
# Out:
# <AxesSubplot:xlabel='BALANCE', ylabel='Count'>

# %%
sns.histplot(x=df['DURATION_CONTACT'], hue=df['SUBSCRIPTION'])
# Out:
# <AxesSubplot:xlabel='DURATION_CONTACT', ylabel='Count'>
